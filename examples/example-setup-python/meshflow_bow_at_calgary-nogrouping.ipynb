# %% [markdown]
# # Build `MESH` Model Setup for the Bow River at Calgary

# %% [markdown]
# We use the `MESHFlow` Python package to build a `MESH` model setup for the Bow River at Banff.

# %% [markdown]
# Let's start by importing the necessary libraries:

# %%
# import necessary libraries
import meshflow

import os

# %% [markdown]
# Now, let's provide necessary information to set up the `MESH` model:

# %%
# main work path - modify
# work_path = 'CHANGE/YOUR/PATH/TO/EXAMPLES/DIRECTORY'
work_path = '..'

config = {
    'riv': os.path.join(work_path, 'bow-at-calgary-shapefiles', 'bcalgary_rivers.shp'),
    'cat': os.path.join(work_path, 'bow-at-calgary-shapefiles', 'bcalgary_subbasins.shp'),
    'landcover': os.path.join(work_path, 'bow-at-calgary-attributes', 'bcalgary_stats_NA_NALCMS_landcover_2020_30m.csv'),
    'forcing_files': os.path.join(work_path, 'bow-at-calgary-forcings'),
    'forcing_vars': {
        "air_pressure": "RDRS_v2.1_P_P0_SFC",
        "specific_humidity": "RDRS_v2.1_P_HU_09944",
        "air_temperature": "RDRS_v2.1_P_TT_09944",
        "wind_speed": "RDRS_v2.1_P_UVC_09944",
        "precipitation": "RDRS_v2.1_A_PR0_SFC",
        "shortwave_radiation": "RDRS_v2.1_P_FB_SFC",
        "longwave_radiation": "RDRS_v2.1_P_FI_SFC",
    },
    'forcing_units': {
        'air_pressure': 'millibar',
        'specific_humidity': 'kilogram / kilogram',
        'air_temperature': 'celsius',
        'wind_speed': 'knot',
        'precipitation': 'meter / hour',
        'shortwave_radiation': 'watt / meter ** 2',
        'longwave_radiation': 'watt / meter ** 2',
    },
    'main_id': 'COMID',
    'ds_main_id': 'NextDownID',
    'landcover_classes': {
        0: 'Unknown',
        1: 'Temperate or sub-polar needleleaf forest',
        2: 'Sub-polar taiga needleleaf forest',
        3: 'Tropical or sub-tropical broadleaf evergreen forest',
        4: 'Tropical or sub-tropical broadleaf deciduous forest',
        5: 'Temperate or sub-polar broadleaf deciduous forest',
        6: 'Mixed forest',
        7: 'Tropical or sub-tropical shrubland',
        8: 'Temperate or sub-polar shrubland',
        9: 'Tropical or sub-tropical grassland',
        10: 'Temperate or sub-polar grassland',
        11: 'Sub-polar or polar shrubland-lichen-moss',
        12: 'Sub-polar or polar grassland-lichen-moss',
        13: 'Sub-polar or polar barren-lichen-moss',
        14: 'Wetland',
        15: 'Cropland',
        16: 'Barren lands',
        17: 'Urban',
        18: 'Water',
        19: 'Snow and Ice',
    },
    'ddb_vars': {
        'river_slope': 'slope',
        'river_length': 'lengthkm',
        'river_class': 'order',
        'maxup': 'maximum_up', # anything in `riv` object can be added!
    },
    'ddb_units': {
        'river_slope': 'dimensionless',
        'river_length': 'kilometer',
        'river_class': 'dimensionless'
    },
    'settings': {
        'core': {
            'forcing_files': 'multiple',
            'forcing_start_date': '1980-01-01 00:00:00',
            'simulation_start_date': '1985-02-12 12:00:00',
            'simulation_end_date': '2010-05-18 18:00:00',
            'forcing_time_zone': 'UTC',
            # 'model_time_zone': 'America/Edmonton',
            'output_path': 'results',
            'landcover_mode': 'fractional',  # change to 'majority' or 'mode' for dominant landcover class
        },
        'class_params': {
            'measurement_heights': {
                'wind_speed': 40,
                'specific_humidity': 40,
                'air_temperature': 40,
                'roughness_length': 50,
            },
            'copyright': {
                'author': 'University of Calgary',
                'location': 'University of Calgary',
            },
            'grus': {
                0: 'needleleaf',
                1: {
                    'class': 'needleleaf',
                    'LNZ0': -1.4,
                },
                2: 'needleleaf',
                3: 'broadleaf',
                4: 'broadleaf',
                5: {
                    'class': 'broadleaf',
                    'rOot': 4,
                },
                6: [
                    {
                        'class': 'needleleaf',
                        'fcan': 0.5,
                        'lnz0': 0.1,
                        'rsmn': 275.13
                    },
                    {
                        'class': 'broadleaf',
                        'fcan': 0.5,
                        'lnz0': 0.21,
                    },
                ],
                (7, 8, 9, 10, 11, 12): 'grass',
                13: 'grass',
                14: 'water',
                15: 'crops',
                16: 'barrenland',
                17: 'urban',
                18: 'water',
                19: 'snow',
            },
        },
        'hydrology_params': {
            'routing': [
                {
                    'R2N': 0.3,
                    'pwr': 0.72,
                },
                {
                    'pwr': 0.32,
                    'flz': 0.13,
                },
            ],
            'hydrology': {
                5: {
                    'ZSNL': 2,
                },
            },
        },
        'run_options': {
            'flags': {
                'etc': {
                    'RUNMODE': 'noroute',
                },
            },
        },
    },
    'outlet_value': -9999,
}

# %% [markdown]
# We can build an "instance" of the workflow class:

# %%
exp1 = meshflow.MESHWorkflow(**config)

# %% [markdown]
# And, we can run it using:

# %%
exp1.run(save_path=os.path.join(work_path, 'outputs'))
# Out:
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:888: UserWarning: `maxup` is not a recognized drainage database variable name
#   warnings.warn(f"`{k}` is not a recognized drainage database variable name")
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:771: UserWarning: Since multiple forcing files are needed, each file will be processed and saved during initialization.
#   warnings.warn(
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:1026: UserWarning: Directory /home/tylerrt/github-repos/meshflow/examples/outputs/forcings already exists. Forcing files will be saved there.
#   warnings.warn(
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:138: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   var = [i for i in ds.dims.keys() if i != 'time']
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:138: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   var = [i for i in ds.dims.keys() if i != 'time']
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:138: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   var = [i for i in ds.dims.keys() if i != 'time']
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:138: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   var = [i for i in ds.dims.keys() if i != 'time']
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:138: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   var = [i for i in ds.dims.keys() if i != 'time']
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:138: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   var = [i for i in ds.dims.keys() if i != 'time']
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:138: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   var = [i for i in ds.dims.keys() if i != 'time']
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:138: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   var = [i for i in ds.dims.keys() if i != 'time']
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:138: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   var = [i for i in ds.dims.keys() if i != 'time']
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:1273: UserWarning: GRU 0 not found in landcover classes. Skipping...
#   warnings.warn(f"GRU {gru} not found in landcover classes. Skipping...")
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:1273: UserWarning: GRU 3 not found in landcover classes. Skipping...
#   warnings.warn(f"GRU {gru} not found in landcover classes. Skipping...")
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:1273: UserWarning: GRU 4 not found in landcover classes. Skipping...
#   warnings.warn(f"GRU {gru} not found in landcover classes. Skipping...")
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:1273: UserWarning: GRU (7, 8, 9, 10, 11, 12) not found in landcover classes. Skipping...
#   warnings.warn(f"GRU {gru} not found in landcover classes. Skipping...")
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:1273: UserWarning: GRU 13 not found in landcover classes. Skipping...
#   warnings.warn(f"GRU {gru} not found in landcover classes. Skipping...")
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:1476: UserWarning: No `model_time_zone` provided in settings['core']. Autodetecting the time zone using `timezonefinder` based on the centroid of the catchment area.
#   warnings.warn(
# /home/tylerrt/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:1496: UserWarning: Autodetected model time zone: America/Denver
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 exp1.run(save_path=os.path.join(work_path, 'outputs'))
#
# File ~/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:804, in MESHWorkflow.run(self, save_path)
#     799 included_processes = self.check_process_parameters(
#     800     options_dict=self.options_dict,
#     801     return_processes=True)
#     803 # Render configuration texts for the MESH instance
# --> 804 self.class_text, self.hydrology_text, self.run_options_text = self.render_configs(
#     805     class_dicts=self.class_dict,
#     806     hydrology_dicts=self.hydrology_dict,
#     807     options_dict=self.run_options_dict,
#     808     process_details=included_processes,
#     809     return_texts=True,
#     810 )
#     812 return
#
# File ~/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:1717, in MESHWorkflow.render_configs(self, class_dicts, hydrology_dicts, options_dict, process_details, return_texts)
#    1713     raise ValueError("`class_dicts`, `hydrology_dicts`, and `options_dict` "
#    1714                      "must be dictionaries")
#    1716 # render CLASS configuration text
# -> 1717 self.class_text = utility.render_class_template(
#    1718     class_info=class_dicts.get('class_info'),
#    1719     class_case=class_dicts.get('class_case'),
#    1720     class_grus=class_dicts.get('class_grus')
#    1721 )
#    1723 # render run options configuration text
#    1724 self.options_text = utility.render_run_options_template(options_dict)
#
# File ~/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/templating.py:206, in render_class_template(class_info, class_case, class_grus, default_header_path, default_params_path, default_case_path, default_lines_path, default_types_path, template_class_jinja_path)
#     203 template = environment.get_template(template_class_jinja_path)
#     205 # create content
# --> 206 content = template.render(
#     207     info_block=class_info,
#     208     case_block=class_case,
#     209     gru_block=gru_block,
#     210     variables="vars",
#     211     comments="comments",
#     212     formats="formats",
#     213     columns="columns",
#     214 )
#     216 return content if content.endswith('\n') else content + '\n'
#
# File ~/virtual-envs/scienv/lib/python3.11/site-packages/jinja2/environment.py:1304, in Template.render(self, *args, **kwargs)
#    1302     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1303 except Exception:
# -> 1304     self.environment.handle_exception()
#
# File ~/virtual-envs/scienv/lib/python3.11/site-packages/jinja2/environment.py:939, in Environment.handle_exception(self, source)
#     934 """Exception handling helper.  This is used internally to either raise
#     935 rewritten exceptions or return a rendered traceback for the template.
#     936 """
#     937 from .debug import rewrite_traceback_stack
# --> 939 raise rewrite_traceback_stack(source=source)
#
# File ~/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/templates/MESH_parameters_CLASS.ini.jinja:240, in top-level template code()
#     238 {# first sub-sub-section #}
#     239 {# put zeros given the order of class #}
# --> 240 {%- set empty_predecessor = "   0.000" * order.get(class) -%}
#     241 {#
#     242     the cursor moves 8 characters (padding of 3 + 0 numbers) times
#
# TypeError: can't multiply sequence by non-int of type 'NoneType'

# %%
exp1.save(output_dir=os.path.join(work_path, 'outputs'))
